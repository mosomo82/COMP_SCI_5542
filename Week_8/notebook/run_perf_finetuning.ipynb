# %% [markdown]
# **Install Required Dependencies**
#
# All the necessary Hugging Face libraries for QLoRA fine-tuning

# %%
# !pip install -q -U transformers peft bitsandbytes trl datasets accelerate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 104.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 528.8/528.8 kB 45.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.5/527.5 kB 48.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 17.0 MB/s eta 0:00:00

# %% [markdown]
# **Run the script**

# %%
# !python peft_finetuning.py
# Out:
# Loading dataset from instruction_dataset.json...
# Loading tokenizer for microsoft/phi-2...
# Loading base model microsoft/phi-2...
# Loading weights: 100% 453/453 [00:21<00:00, 20.92it/s]
# Applying formatting function to train dataset: 100% 100/100 [00:00<00:00, 3819.88 examples/s]
# Adding EOS to train dataset: 100% 100/100 [00:00<00:00, 2056.26 examples/s]
# Tokenizing train dataset: 100% 100/100 [00:00<00:00, 223.34 examples/s]
# Truncating train dataset: 100% 100/100 [00:00<00:00, 2751.86 examples/s]
# Starting training...
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'pad_token_id': 50256}.
# {'loss': '2.769', 'grad_norm': '1.078', 'learning_rate': '0.000176', 'entropy': '2.776', 'num_tokens': '6454', 'mean_token_accuracy': '0.484', 'epoch': '0.4'}
# ...

# %% [markdown]
# **Download the fine-tuned model**

# %%
# !zip -r adapted_model.zip adapted_model/
from google.colab import files
files.download('adapted_model.zip')
# Out:
#   adding: adapted_model/ (stored 0%)
#   adding: adapted_model/adapter_config.json (deflated 57%)
#   adding: adapted_model/tokenizer.json (deflated 82%)
#   adding: adapted_model/tokenizer_config.json (deflated 49%)
#   adding: adapted_model/README.md (deflated 65%)
#   adding: adapted_model/adapter_model.safetensors (deflated 22%)
